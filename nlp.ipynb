# %%
from main import PlagarismChecker
# Out:
# /Users/isobarbaric/miniforge3/lib/python3.9/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (None)/charset_normalizer (3.0.1) doesn't match a supported version!
#   warnings.warn(

# %%
text = "Dogs are one of the most popular domestic pets and have been bred for thousands of years for various purposes, such as hunting, herding, and guarding. They belong to the Canidae family and are descendants of wolves. Today, dogs come in a wide range of breeds, each with its own unique physical appearance and personality traits. They are known for their loyalty, affection, and obedience to their owners. Dogs are also highly trainable and can be taught various commands and tricks, which makes them useful for various tasks, such as assistance for people with disabilities and law enforcement. They also make great companions for children and adults alike, providing comfort and emotional support."

# %%
# process all text
relevant_links = PlagarismChecker.google_search('dog', num_pages=1)
# Out:
# https://www.google.com/search?q=dog&start=0

# %%
extracted_content = PlagarismChecker.extract_content(relevant_links)

# %%
import nltk
def get_part_of_speech(provided_word: str) -> str:
    _, part_of_speech = nltk.pos_tag([provided_word])[0]
    if 'NN' in part_of_speech:
        return 'n'
    if 'VB' in part_of_speech:
        return 'v'
    if 'JJ' in part_of_speech:
        return 'a'
    if 'RB' in part_of_speech:
        return 'r'
    return 'n'

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

def text_preparation(text: str):
    # tokenize, lowercase
    tokenized_content = [word.lower() for word in word_tokenize(text)]

    # removing stop words
    filtered_words = [word for word in tokenized_content if word not in stopwords.words('english')]

    # data cleaning
    cleaned_content = [word for word in filtered_words if len(word) > 1]

    # lemmatization
    words = []
    lemmatizer = WordNetLemmatizer()
    for word in cleaned_content:
        words.append(lemmatizer.lemmatize(word, get_part_of_speech(word)))
    return words

# %% [markdown]
# data cleaning

# %% [markdown]
# 1. tokenization, lowercase

# %%
from nltk import word_tokenize

# %%
tokenized_content = []

# %%
for article in extracted_content:
    tokenized_content.append([word.lower() for word in word_tokenize(article)])

# %%
tokenized_content[0]
# Out:
# ['|dog|',
#  'domesticated',
#  '|scientific',
#  'classification|',
#  '|kingdom',
#  ':',
#  '||animalia|',
#  '|phylum',
#  ':',
#  '||chordata|',
#  '|class',
#  ':',
#  '||mammalia|',
#  '|order',
#  ':',
#  '||carnivora|',
#  '|family',
#  ':',
#  '||canidae|',
#  '|genus',
#  ':',
#  '||canis|',
#  '|species',
#  ':',
#  '|',
#  'c.',
#  'familiaris',
#  '|binomial',
#  'name|',
#  '|canis',
#  'familiaris|',
#  '|synonyms',
#  '[',
#  '3',
#  ']',
#  '|',
#  '|',
#  '|',
#  'list',
#  'the',
#  'dog',
#  '(',
#  'canis',
#  'familiaris',
#  '[',
#  '4',
#  ']',
#  '[',
#  '5',
#  ']',
#  'or',
#  'canis',
#  'lupus',
#  'familiaris',
#  '[',
#  '5',
#  ']',
#  ')',
#  'is',
#  'a',
#  'domesticated',
#  'descendant',
#  'of',
#  'the',
#  'wolf',
#  '.',
#  'also',
#  'called',
#  'the',
#  'domestic',
#  'dog',
#  ',',
#  'it',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'extinct',
#  'pleistocene',
#  'wolf',
#  ',',
#  '[',
#  '6',
#  ']',
#  '[',
#  '7',
#  ']',
#  'and',
#  'the',
#  'modern',
#  'wolf',
#  'is',
#  'the',
#  'dog',
#  "'s",
#  'nearest',
#  'living',
#  'relative',
#  '.',
#  '[',
#  '8',
#  ']',
#  'dogs',
#  'were',
#  'the',
#  'first',
#  'species',
#  'to',
#  'be',
#  'domesticated',
#  '[',
#  '9',
#  ']',
#  '[',
#  '8',
#  ']',
#  'by',
#  'hunter-gatherers',
#  'over',
#  '15,000',
#  'years',
#  'ago',
#  '[',
#  '7',
#  ']',
#  'before',
#  'the',
#  'development',
#  'of',
#  'agriculture',
#  '.',
#  '[',
#  '1',
#  ']',
#  'due',
#  'to',
#  'their',
#  'long',
#  'association',
#  'with',
#  'humans',
#  ',',
#  'dogs',
#  'have',
#  'expanded',
#  'to',
#  'a',
#  'large',
#  'number',
#  'of',
#  'domestic',
#  'individuals',
#  '[',
#  '10',
#  ']',
#  'and',
#  'gained',
#  'the',
#  'ability',
#  'to',
#  'thrive',
#  'on',
#  'a',
#  'starch-rich',
#  'diet',
#  'that',
#  'would',
#  'be',
#  'inadequate',
#  'for',
#  'other',
#  'canids',
#  '.',
#  '[',
#  '11',
#  ']',
#  'the',
#  'dog',
#  'has',
#  'been',
#  'selectively',
#  'bred',
#  'over',
#  'millennia',
#  'for',
#  'various',
#  'behaviors',
#  ',',
#  'sensory',
#  'capabilities',
#  ',',
#  'and',
#  'physical',
#  'attributes',
#  '.',
#  '[',
#  '12',
#  ']',
#  'dog',
#  'breeds',
#  'vary',
#  'widely',
#  'in',
#  'shape',
#  ',',
#  'size',
#  ',',
#  'and',
#  'color',
#  '.',
#  'they',
#  'perform',
#  'many',
#  'roles',
#  'for',
#  'humans',
#  ',',
#  'such',
#  'as',
#  'hunting',
#  ',',
#  'herding',
#  ',',
#  'pulling',
#  'loads',
#  ',',
#  'protection',
#  ',',
#  'assisting',
#  'police',
#  'and',
#  'the',
#  'military',
#  ',',
#  'companionship',
#  ',',
#  'therapy',
#  ',',
#  'and',
#  'aiding',
#  'disabled',
#  'people',
#  '.',
#  'over',
#  'the',
#  'millennia',
#  ',',
#  'dogs',
#  'became',
#  'uniquely',
#  'adapted',
#  'to',
#  'human',
#  'behavior',
#  ',',
#  'and',
#  'the',
#  'human-canine',
#  'bond',
#  'has',
#  'been',
#  'a',
#  'topic',
#  'of',
#  'frequent',
#  'study',
#  '.',
#  '[',
#  '13',
#  ']',
#  'this',
#  'influence',
#  'on',
#  'human',
#  'society',
#  'has',
#  'given',
#  'them',
#  'the',
#  'sobriquet',
#  'of',
#  '``',
#  'man',
#  "'s",
#  'best',
#  'friend',
#  "''",
#  '.',
#  '[',
#  '14',
#  ']',
#  'taxonomy',
#  'in',
#  '1758',
#  ',',
#  'the',
#  'swedish',
#  'botanist',
#  'and',
#  'zoologist',
#  'carl',
#  'linnaeus',
#  'published',
#  'in',
#  'his',
#  'systema',
#  'naturae',
#  ',',
#  'the',
#  'two-word',
#  'naming',
#  'of',
#  'species',
#  '(',
#  'binomial',
#  'nomenclature',
#  ')',
#  '.',
#  'canis',
#  'is',
#  'the',
#  'latin',
#  'word',
#  'meaning',
#  '``',
#  'dog',
#  "''",
#  ',',
#  '[',
#  '15',
#  ']',
#  'and',
#  'under',
#  'this',
#  'genus',
#  ',',
#  'he',
#  'listed',
#  'the',
#  'domestic',
#  'dog',
#  ',',
#  'the',
#  'wolf',
#  ',',
#  'and',
#  'the',
#  'golden',
#  'jackal',
#  '.',
#  'he',
#  'classified',
#  'the',
#  'domestic',
#  'dog',
#  'as',
#  'canis',
#  'familiaris',
#  'and',
#  ',',
#  'on',
#  'the',
#  'next',
#  'page',
#  ',',
#  'classified',
#  'the',
#  'grey',
#  'wolf',
#  'as',
#  'canis',
#  'lupus',
#  '.',
#  '[',
#  '2',
#  ']',
#  'linnaeus',
#  'considered',
#  'the',
#  'dog',
#  'to',
#  'be',
#  'a',
#  'separate',
#  'species',
#  'from',
#  'the',
#  'wolf',
#  'because',
#  'of',
#  'its',
#  'upturning',
#  'tail',
#  '(',
#  'cauda',
#  'recurvata',
#  ')',
#  ',',
#  'which',
#  'is',
#  'not',
#  'found',
#  'in',
#  'any',
#  'other',
#  'canid',
#  '.',
#  '[',
#  '16',
#  ']',
#  'in',
#  '1999',
#  ',',
#  'a',
#  'study',
#  'of',
#  'mitochondrial',
#  'dna',
#  '(',
#  'mtdna',
#  ')',
#  'indicated',
#  'that',
#  'the',
#  'domestic',
#  'dog',
#  'may',
#  'have',
#  'originated',
#  'from',
#  'the',
#  'grey',
#  'wolf',
#  ',',
#  'with',
#  'the',
#  'dingo',
#  'and',
#  'new',
#  'guinea',
#  'singing',
#  'dog',
#  'breeds',
#  'having',
#  'developed',
#  'at',
#  'a',
#  'time',
#  'when',
#  'human',
#  'communities',
#  'were',
#  'more',
#  'isolated',
#  'from',
#  'each',
#  'other',
#  '.',
#  '[',
#  '17',
#  ']',
#  'in',
#  'the',
#  'third',
#  'edition',
#  'of',
#  'mammal',
#  'species',
#  'of',
#  'the',
#  'world',
#  'published',
#  'in',
#  '2005',
#  ',',
#  'the',
#  'mammalogist',
#  'w.',
#  'christopher',
#  'wozencraft',
#  'listed',
#  'under',
#  'the',
#  'wolf',
#  'canis',
#  'lupus',
#  'its',
#  'wild',
#  'subspecies',
#  'and',
#  'proposed',
#  'two',
#  'additional',
#  'subspecies',
#  ',',
#  'which',
#  'formed',
#  'the',
#  'domestic',
#  'dog',
#  'clade',
#  ':',
#  'familiaris',
#  ',',
#  'as',
#  'named',
#  'by',
#  'linnaeus',
#  'in',
#  '1758',
#  'and',
#  ',',
#  'dingo',
#  'named',
#  'by',
#  'meyer',
#  'in',
#  '1793',
#  '.',
#  'wozencraft',
#  'included',
#  'hallstromi',
#  '(',
#  'the',
#  'new',
#  'guinea',
#  'singing',
#  'dog',
#  ')',
#  'as',
#  'another',
#  'name',
#  '(',
#  'junior',
#  'synonym',
#  ')',
#  'for',
#  'the',
#  'dingo',
#  '.',
#  'wozencraft',
#  'referred',
#  'to',
#  'the',
#  'mtdna',
#  'study',
#  'as',
#  'one',
#  'of',
#  'the',
#  'guides',
#  'informing',
#  'his',
#  'decision',
#  '.',
#  '[',
#  '3',
#  ']',
#  'mammalogists',
#  'have',
#  'noted',
#  'the',
#  'inclusion',
#  'of',
#  'familiaris',
#  'and',
#  'dingo',
#  'together',
#  'under',
#  'the',
#  '``',
#  'domestic',
#  'dog',
#  "''",
#  'clade',
#  '[',
#  '18',
#  ']',
#  'with',
#  'some',
#  'debating',
#  'it',
#  '.',
#  '[',
#  '19',
#  ']',
#  'in',
#  '2019',
#  ',',
#  'a',
#  'workshop',
#  'hosted',
#  'by',
#  'the',
#  'iucn/species',
#  'survival',
#  'commission',
#  "'s",
#  'canid',
#  'specialist',
#  'group',
#  'considered',
#  'the',
#  'dingo',
#  'and',
#  'the',
#  'new',
#  'guinea',
#  'singing',
#  'dog',
#  'to',
#  'be',
#  'feral',
#  'canis',
#  'familiaris',
#  'and',
#  'therefore',
#  'did',
#  'not',
#  'assess',
#  'them',
#  'for',
#  'the',
#  'iucn',
#  'red',
#  'list',
#  'of',
#  'threatened',
#  'species',
#  '.',
#  '[',
#  '4',
#  ']',
#  'evolution',
#  'the',
#  'cretaceous–paleogene',
#  'extinction',
#  'event',
#  'occurred',
#  '66',
#  'million',
#  'years',
#  'ago',
#  'and',
#  'brought',
#  'an',
#  'end',
#  'to',
#  'the',
#  'non-avian',
#  'dinosaurs',
#  'and',
#  'the',
#  'appearance',
#  'of',
#  'the',
#  'first',
#  'carnivorans',
#  '.',
#  '[',
#  '20',
#  ']',
#  'the',
#  'name',
#  'carnivoran',
#  'is',
#  'given',
#  'to',
#  'a',
#  'member',
#  'of',
#  'the',
#  'order',
#  'carnivora',
#  '.',
#  'carnivorans',
#  'possess',
#  'a',
#  'common',
#  'arrangement',
#  'of',
#  'teeth',
#  'called',
#  'carnassials',
#  ',',
#  'in',
#  'which',
#  'the',
#  'first',
#  'lower',
#  'molar',
#  'and',
#  'the',
#  'last',
#  'upper',
#  'premolar',
#  'possess',
#  'blade-like',
#  'enamel',
#  'crowns',
#  'that',
#  'act',
#  'similar',
#  'to',
#  'a',
#  'pair',
#  'of',
#  'shears',
#  'for',
#  'cutting',
#  'meat',
#  '.',
#  'this',
#  'dental',
#  'arrangement',
#  'has',
#  'been',
#  'modified',
#  'by',
#  'adaptation',
#  'over',
#  'the',
#  'past',
#  '60',
#  'million',
#  'years',
#  'for',
#  'diets',
#  'composed',
#  'of',
#  'meat',
#  ',',
#  'for',
#  'crushing',
#  'vegetation',
#  ',',
#  'or',
#  'for',
#  'the',
#  'loss',
#  'of',
#  'the',
#  'carnassial',
#  'function',
#  'altogether',
#  'as',
#  'in',
#  'seals',
#  ',',
#  'sea',
#  'lions',
#  ',',
#  'and',
#  'walruses',
#  '.',
#  'today',
#  ',',
#  'not',
#  'all',
#  'carnivorans',
#  'are',
#  'carnivores',
#  ',',
#  'such',
#  'as',
#  'the',
#  'insect-eating',
#  'aardwolf',
#  '.',
#  '[',
#  '5',
#  ']',
#  'the',
#  'carnivoran',
#  'ancestors',
#  'of',
#  'the',
#  'dog-like',
#  'caniforms',
#  'and',
#  'the',
#  'cat-like',
#  'feliforms',
#  'began',
#  'their',
#  'separate',
#  'evolutionary',
#  'paths',
#  'just',
#  'after',
#  'the',
#  'end',
#  'of',
#  'the',
#  'dinosaurs',
#  '.',
#  'the',
#  'first',
#  'members',
#  'of',
#  'the',
#  'dog',
#  'family',
#  'canidae',
#  'appeared',
#  '40',
#  'million',
#  'years',
#  'ago',
#  ',',
#  '[',
#  '21',
#  ']',
#  'of',
#  'which',
#  'only',
#  'its',
#  'subfamily',
#  'the',
#  'caninae',
#  'survives',
#  'today',
#  'in',
#  'the',
#  'form',
#  'of',
#  'the',
#  'wolf-like',
#  'and',
#  'fox-like',
#  'canines',
#  '.',
#  'within',
#  'the',
#  'caninae',
#  ',',
#  'the',
#  'first',
#  'members',
#  'of',
#  'genus',
#  'canis',
#  'appeared',
#  'six',
#  'million',
#  'years',
#  'ago',
#  ',',
#  '[',
#  '15',
#  ']',
#  'the',
#  'ancestors',
#  'of',
#  'modern',
#  'domestic',
#  'dogs',
#  ',',
#  'wolves',
#  ',',
#  'coyotes',
#  ',',
#  'and',
#  'golden',
#  'jackals',
#  '.',
#  'domestication',
#  'the',
#  'earliest',
#  'remains',
#  'generally',
#  'accepted',
#  'to',
#  'be',
#  'those',
#  'of',
#  'a',
#  'domesticated',
#  'dog',
#  'were',
#  'discovered',
#  'in',
#  'bonn-oberkassel',
#  ',',
#  'germany',
#  '.',
#  'contextual',
#  ',',
#  'isotopic',
#  ',',
#  'genetic',
#  ',',
#  'and',
#  'morphological',
#  'evidence',
#  'shows',
#  'that',
#  'this',
#  'dog',
#  'was',
#  'not',
#  'a',
#  'local',
#  'wolf',
#  '.',
#  '[',
#  '22',
#  ']',
#  'the',
#  'dog',
#  'was',
#  'dated',
#  'to',
#  '14,223',
#  'years',
#  'ago',
#  'and',
#  'was',
#  'found',
#  'buried',
#  'along',
#  'with',
#  'a',
#  'man',
#  'and',
#  'a',
#  'woman',
#  ',',
#  'all',
#  'three',
#  'having',
#  'been',
#  'sprayed',
#  'with',
#  'red',
#  'hematite',
#  'powder',
#  'and',
#  'buried',
#  'under',
#  'large',
#  ',',
#  'thick',
#  'basalt',
#  'blocks',
#  '.',
#  'the',
#  'dog',
#  'had',
#  'died',
#  'of',
#  'canine',
#  'distemper',
#  '.',
#  '[',
#  '23',
#  ']',
#  'earlier',
#  'remains',
#  'dating',
#  'back',
#  'to',
#  '30,000',
#  'years',
#  'ago',
#  'have',
#  'been',
#  'described',
#  'as',
#  'paleolithic',
#  'dogs',
#  ',',
#  'but',
#  'their',
#  'status',
#  'as',
#  'dogs',
#  'or',
#  'wolves',
#  'remains',
#  'debated',
#  '[',
#  '24',
#  ']',
#  'because',
#  'considerable',
#  'morphological',
#  'diversity',
#  'existed',
#  'among',
#  'wolves',
#  'during',
#  'the',
#  'late',
#  'pleistocene',
#  '.',
#  '[',
#  '1',
#  ']',
#  'this',
#  ...]

# %% [markdown]
# 2. remove stop words

# %%
intermediate_content = []

# %%
from nltk.corpus import stopwords

# %%
for article in tokenized_content:
    filtered_words = [word for word in article if word not in stopwords.words('english')]
    intermediate_content.append(filtered_words)

# %%
intermediate_content[1]
# Out:
# ['-',
#  'common',
#  'name',
#  ':',
#  '-',
#  'domestic',
#  'dogs',
#  '-',
#  'scientific',
#  'name',
#  ':',
#  '-',
#  'canis',
#  'familiaris',
#  '-',
#  'type',
#  ':',
#  '-',
#  'mammals',
#  '-',
#  'diet',
#  ':',
#  '-',
#  'omnivore',
#  '-',
#  'group',
#  'name',
#  ':',
#  '-',
#  'pack',
#  '-',
#  'average',
#  'life',
#  'span',
#  'wild',
#  ':',
#  '-',
#  '12',
#  'years',
#  '-',
#  'size',
#  ':',
#  '-',
#  'five',
#  '35',
#  'inches',
#  'shoulder',
#  '-',
#  'weight',
#  ':',
#  '-',
#  'three',
#  '250',
#  'pounds',
#  '-',
#  'iucn',
#  'red',
#  'list',
#  'status',
#  ':',
#  '-',
#  'evaluated',
#  '-',
#  'current',
#  'population',
#  'trend',
#  ':',
#  '-',
#  'unknown',
#  'domestic',
#  'dog',
#  '?',
#  'term',
#  '“',
#  'domestic',
#  'dog',
#  '”',
#  'refers',
#  'several',
#  'hundred',
#  'breeds',
#  'dog',
#  'world',
#  'today',
#  '.',
#  'animals',
#  'vary',
#  'drastically',
#  'appearance',
#  ',',
#  'every',
#  'dog—from',
#  'chihuahua',
#  'great',
#  'dane—is',
#  'member',
#  'species',
#  ',',
#  'canis',
#  'familiaris',
#  '.',
#  'separates',
#  'domestic',
#  'dogs',
#  'wild',
#  'canines',
#  ',',
#  'coyotes',
#  ',',
#  'foxes',
#  ',',
#  'wolves',
#  '.',
#  'domestic',
#  'dogs',
#  'mostly',
#  'kept',
#  'pets',
#  ',',
#  'though',
#  'many',
#  'breeds',
#  'capable',
#  'surviving',
#  ',',
#  'whether',
#  '’',
#  'forest',
#  'city',
#  'streets',
#  '.',
#  'third',
#  'households',
#  'worldwide',
#  'dog',
#  ',',
#  'according',
#  '2016',
#  'consumer',
#  'insights',
#  'study',
#  '.',
#  'makes',
#  'domestic',
#  'dog',
#  'popular',
#  'pet',
#  'planet',
#  '.',
#  'evolutionary',
#  'origins',
#  'dogs',
#  'descend',
#  'species',
#  'wolf',
#  ',',
#  'gray',
#  'wolf',
#  '(',
#  'canis',
#  'lupus',
#  ')',
#  ',',
#  'like',
#  'many',
#  'people',
#  'assume',
#  '.',
#  'fact',
#  ',',
#  'dna',
#  'evidence',
#  'suggests',
#  'now-extinct',
#  'wolf',
#  'ancestor',
#  'modern',
#  'dogs',
#  'eurasian',
#  '.',
#  'however',
#  ',',
#  'scientists',
#  'still',
#  'working',
#  'understand',
#  'exactly',
#  'species',
#  'gave',
#  'rise',
#  'dogs',
#  '.',
#  'dogs',
#  'broke',
#  'wild',
#  'ancestors',
#  'also',
#  'matter',
#  'mystery',
#  ',',
#  'genetics',
#  'suggest',
#  'occurred',
#  '15,000',
#  '30,000',
#  'years',
#  'ago',
#  '.',
#  '’',
#  'impossible',
#  'say',
#  'exactly',
#  'wild',
#  'wolf',
#  'species',
#  'became',
#  'domesticated',
#  'dog',
#  ',',
#  'scientists',
#  'believe',
#  'process',
#  'happened',
#  'gradually',
#  'wolves',
#  'became',
#  'comfortable',
#  'humans',
#  '.',
#  'perhaps',
#  'wolves',
#  'started',
#  'path',
#  'simply',
#  'eating',
#  'human',
#  'scraps',
#  '.',
#  'many',
#  'generations',
#  'later',
#  ',',
#  'humans',
#  'might',
#  'encouraged',
#  'wolves',
#  'stay',
#  'near',
#  'actively',
#  'feeding',
#  '.',
#  'later',
#  'still',
#  ',',
#  'wolves',
#  'may',
#  'welcomed',
#  'human',
#  'home',
#  'eventually',
#  'bred',
#  'encourage',
#  'certain',
#  'traits',
#  '.',
#  'thought',
#  'unfolded',
#  'thousands',
#  'years',
#  '.',
#  'dog',
#  'breeds',
#  'today',
#  ',',
#  'many',
#  'dogs',
#  'know',
#  'love',
#  'product',
#  'selective',
#  'breeding',
#  'individuals',
#  'desirable',
#  'traits',
#  ',',
#  'either',
#  'physical',
#  'behavioral',
#  '.',
#  'instance',
#  ',',
#  'around',
#  '9,500',
#  'years',
#  'ago',
#  ',',
#  'ancient',
#  'peoples',
#  'began',
#  'breeding',
#  'dogs',
#  'best',
#  'able',
#  'survive',
#  'work',
#  'cold',
#  '.',
#  'dogs',
#  'would',
#  'become',
#  'family',
#  'sled',
#  'dogs—including',
#  'breeds',
#  'huskies',
#  'malamutes—that',
#  'remains',
#  'relatively',
#  'unchanged',
#  'today',
#  '.',
#  'similarly',
#  ',',
#  'humans',
#  'bred',
#  'german',
#  'shepherds',
#  'ability',
#  'herd',
#  'livestock',
#  ',',
#  'labrador',
#  'retrievers',
#  'help',
#  'collect',
#  'ducks',
#  'game',
#  'felled',
#  'hunters',
#  ',',
#  'sausage-shaped',
#  'dachshunds',
#  'ability',
#  'rush',
#  'burrow',
#  'badger',
#  '.',
#  'many',
#  'breeds',
#  'created',
#  'fill',
#  'human',
#  'needs',
#  ',',
#  'home',
#  'protection',
#  'vermin',
#  'control',
#  '.',
#  'certain',
#  'breeds',
#  'also',
#  'created',
#  'make',
#  'dogs',
#  'desirable',
#  'companions',
#  '.',
#  'instance',
#  ',',
#  'labradoodle',
#  ',',
#  'combines',
#  'traits',
#  'labrador',
#  'retriever',
#  'poodle',
#  ',',
#  'invented',
#  'attempt',
#  'create',
#  'hypoallergenic',
#  'guide',
#  'dog',
#  '.',
#  'modern',
#  'working',
#  'dogs',
#  'people',
#  'rely',
#  'less',
#  'dogs',
#  'daily',
#  'tasks',
#  'past',
#  ',',
#  'still',
#  'many',
#  'modern',
#  'jobs',
#  'pooches',
#  '.',
#  'domestic',
#  'dog',
#  '’',
#  'sense',
#  'smell',
#  '10,000',
#  '100,000',
#  'better',
#  ',',
#  'canines',
#  'assist',
#  'law',
#  'enforcement',
#  'sniffing',
#  'drugs',
#  ',',
#  'explosives',
#  ',',
#  'even',
#  'electronics',
#  '.',
#  'also',
#  'help',
#  'conservationists',
#  'find',
#  'protect',
#  'endangered',
#  'species',
#  'using',
#  'super-powered',
#  'schnozzes',
#  '.',
#  'assist',
#  'search',
#  'rescue',
#  'teams',
#  'wake',
#  'natural',
#  'disasters',
#  'reports',
#  'people',
#  'lost',
#  'outdoors',
#  '.',
#  'dogs',
#  'trained',
#  'warn',
#  'hidden',
#  'explosives',
#  'enemies',
#  'serve',
#  'allies',
#  'military',
#  'operations',
#  '.',
#  'dogs',
#  'assist',
#  'police',
#  'looking',
#  'jail',
#  'escapees',
#  'bodies',
#  'murder',
#  'victims',
#  '.',
#  'partner',
#  'instead',
#  'customs',
#  'officials',
#  'searching',
#  'contraband',
#  ',',
#  'drugs',
#  'elephant',
#  'ivory',
#  '.',
#  'still',
#  'others',
#  'lead',
#  'way',
#  'tracking',
#  'poachers',
#  ',',
#  'patrolling',
#  'cargo',
#  'ships',
#  'rats',
#  'might',
#  'escape',
#  'distant',
#  'harbors',
#  ',',
#  'exposing',
#  'forest',
#  'insect',
#  'pests',
#  'shipments',
#  'wood',
#  'abroad',
#  '.',
#  'similarly',
#  ',',
#  'dogs',
#  'sniff',
#  'early',
#  'signs',
#  'parkinson',
#  '’',
#  'disease',
#  ',',
#  'diabetes',
#  ',',
#  'several',
#  'types',
#  'cancer',
#  ',',
#  'oncoming',
#  'epileptic',
#  'seizures',
#  ',',
#  'antibiotic-resistant',
#  'bacteria',
#  '.',
#  'guide',
#  'deaf',
#  'blind',
#  'people',
#  ',',
#  'help',
#  'people',
#  'autism',
#  'post-traumatic',
#  'stress',
#  'disorder',
#  'manage',
#  'anxiety',
#  '.',
#  'living',
#  'dogs',
#  'dogs',
#  'mix',
#  'breeds—in',
#  '2015',
#  ',',
#  'one',
#  'study',
#  'estimated',
#  '5',
#  'percent',
#  'dogs',
#  'shelters',
#  'purebred',
#  '.',
#  'dogs',
#  'come',
#  'sizes',
#  ',',
#  'shapes',
#  ',',
#  'colors',
#  ',',
#  'animals',
#  'also',
#  'come',
#  'spectrum',
#  'temperaments',
#  '.',
#  'bulldog',
#  'might',
#  'look',
#  'fierce',
#  'cuddly',
#  'kitten',
#  ',',
#  'whereas',
#  'cute',
#  'cocker',
#  'spaniel',
#  'might',
#  'nip',
#  'finger',
#  'without',
#  'thinking',
#  'twice',
#  '.',
#  'animal',
#  'handling',
#  'expert',
#  'jack',
#  'hanna',
#  'recommends',
#  'teaching',
#  'children',
#  'always',
#  'exercise',
#  'caution',
#  'around',
#  'dog',
#  'know',
#  '.',
#  'instance',
#  ',',
#  'says',
#  'kids',
#  'ask',
#  'permission',
#  'dog',
#  '’',
#  'owner',
#  'trying',
#  'pet',
#  'play',
#  'animal',
#  '.',
#  'offering',
#  'outstretched',
#  'hand',
#  'also',
#  'allows',
#  'dog',
#  'familiarize',
#  'new',
#  'person',
#  'reaching',
#  'behind',
#  'head',
#  '’',
#  'see',
#  '’',
#  ',',
#  'might',
#  'make',
#  'dog',
#  'nervous',
#  'scared',
#  '.',
#  'finally',
#  ',',
#  'never',
#  'allow',
#  'children',
#  'put',
#  'faces',
#  'near',
#  'dog',
#  '’',
#  'muzzle',
#  '.',
#  '“',
#  '’',
#  'care',
#  'kind',
#  'dog',
#  ',',
#  '”',
#  'hanna',
#  'told',
#  'national',
#  'geographic',
#  '.',
#  '“',
#  'owner',
#  'may',
#  'say',
#  ',',
#  '‘',
#  'well',
#  ',',
#  'dog',
#  '’',
#  'never',
#  'bit',
#  'anyone',
#  'before.',
#  '’',
#  '’',
#  'point',
#  '.',
#  'point',
#  'happen.',
#  '”',
#  'course',
#  ',',
#  'dogs',
#  'cared',
#  'properly',
#  'treated',
#  'respect',
#  ',',
#  'incredibly',
#  'loving',
#  ',',
#  'playful',
#  ',',
#  'intelligent',
#  'companions',
#  '.',
#  '’',
#  ',',
#  'understanding',
#  'dogs',
#  'come',
#  ',',
#  'pet',
#  'owners',
#  'might',
#  'learn',
#  'appreciate',
#  'canines',
#  'even',
#  '.',
#  ',',
#  'yipping',
#  'tail-wagging',
#  'dog',
#  'performs',
#  'grab',
#  'bag',
#  'treats',
#  'carry-overs',
#  'ancestors',
#  'needed',
#  'communicate',
#  'members',
#  'social',
#  'group',
#  '.',
#  'chasing',
#  'sticks',
#  'balls',
#  'may',
#  'linked',
#  'pursuit',
#  'prey',
#  ',',
#  'digging',
#  'carpet',
#  'dog',
#  'bed',
#  'echoes',
#  'wild',
#  'canid',
#  'would',
#  'prepare',
#  'sleeping',
#  'area',
#  '.',
#  'time',
#  'fido',
#  'stops',
#  'sniff',
#  'fire',
#  'hydrant',
#  'walk',
#  ',',
#  '’',
#  'analyzing',
#  'pheromones',
#  'left',
#  'behind',
#  'another',
#  'dog',
#  '’',
#  'urine',
#  '.',
#  'take',
#  'behaviors',
#  'granted',
#  'dogs',
#  'become',
#  '“',
#  'man',
#  '’',
#  'best',
#  'friend.',
#  '”',
#  'deep',
#  'inside',
#  'every',
#  'pit',
#  'bull',
#  'pomeranian',
#  ',',
#  'lie',
#  'hints',
#  'past',
#  '.',
#  'editor',
#  "'s",
#  'note',
#  ':',
#  'bringing',
#  'dog',
#  'household',
#  'major',
#  'responsibility',
#  '.',
#  '1.6',
#  'million',
#  'dogs',
#  'ended',
#  'shelters',
#  '2020',
#  '.',
#  'learn',
#  'keep',
#  'dog',
#  'happy',
#  'healthy',
#  'national',
#  'geographic',
#  'book',
#  'complete',
#  'guide',
#  'pet',
#  'health',
#  ',',
#  'behavior',
#  ',',
#  'happiness',
#  '.']

# %% [markdown]
# 3. clean

# %%
cleaned_content = []

# %%
for article in intermediate_content:
    cleaned_content.append([word for word in article if len(word) > 1])

# %%
cleaned_content[1]
# Out:
# ['common',
#  'name',
#  'domestic',
#  'dogs',
#  'scientific',
#  'name',
#  'canis',
#  'familiaris',
#  'type',
#  'mammals',
#  'diet',
#  'omnivore',
#  'group',
#  'name',
#  'pack',
#  'average',
#  'life',
#  'span',
#  'wild',
#  '12',
#  'years',
#  'size',
#  'five',
#  '35',
#  'inches',
#  'shoulder',
#  'weight',
#  'three',
#  '250',
#  'pounds',
#  'iucn',
#  'red',
#  'list',
#  'status',
#  'evaluated',
#  'current',
#  'population',
#  'trend',
#  'unknown',
#  'domestic',
#  'dog',
#  'term',
#  'domestic',
#  'dog',
#  'refers',
#  'several',
#  'hundred',
#  'breeds',
#  'dog',
#  'world',
#  'today',
#  'animals',
#  'vary',
#  'drastically',
#  'appearance',
#  'every',
#  'dog—from',
#  'chihuahua',
#  'great',
#  'dane—is',
#  'member',
#  'species',
#  'canis',
#  'familiaris',
#  'separates',
#  'domestic',
#  'dogs',
#  'wild',
#  'canines',
#  'coyotes',
#  'foxes',
#  'wolves',
#  'domestic',
#  'dogs',
#  'mostly',
#  'kept',
#  'pets',
#  'though',
#  'many',
#  'breeds',
#  'capable',
#  'surviving',
#  'whether',
#  'forest',
#  'city',
#  'streets',
#  'third',
#  'households',
#  'worldwide',
#  'dog',
#  'according',
#  '2016',
#  'consumer',
#  'insights',
#  'study',
#  'makes',
#  'domestic',
#  'dog',
#  'popular',
#  'pet',
#  'planet',
#  'evolutionary',
#  'origins',
#  'dogs',
#  'descend',
#  'species',
#  'wolf',
#  'gray',
#  'wolf',
#  'canis',
#  'lupus',
#  'like',
#  'many',
#  'people',
#  'assume',
#  'fact',
#  'dna',
#  'evidence',
#  'suggests',
#  'now-extinct',
#  'wolf',
#  'ancestor',
#  'modern',
#  'dogs',
#  'eurasian',
#  'however',
#  'scientists',
#  'still',
#  'working',
#  'understand',
#  'exactly',
#  'species',
#  'gave',
#  'rise',
#  'dogs',
#  'dogs',
#  'broke',
#  'wild',
#  'ancestors',
#  'also',
#  'matter',
#  'mystery',
#  'genetics',
#  'suggest',
#  'occurred',
#  '15,000',
#  '30,000',
#  'years',
#  'ago',
#  'impossible',
#  'say',
#  'exactly',
#  'wild',
#  'wolf',
#  'species',
#  'became',
#  'domesticated',
#  'dog',
#  'scientists',
#  'believe',
#  'process',
#  'happened',
#  'gradually',
#  'wolves',
#  'became',
#  'comfortable',
#  'humans',
#  'perhaps',
#  'wolves',
#  'started',
#  'path',
#  'simply',
#  'eating',
#  'human',
#  'scraps',
#  'many',
#  'generations',
#  'later',
#  'humans',
#  'might',
#  'encouraged',
#  'wolves',
#  'stay',
#  'near',
#  'actively',
#  'feeding',
#  'later',
#  'still',
#  'wolves',
#  'may',
#  'welcomed',
#  'human',
#  'home',
#  'eventually',
#  'bred',
#  'encourage',
#  'certain',
#  'traits',
#  'thought',
#  'unfolded',
#  'thousands',
#  'years',
#  'dog',
#  'breeds',
#  'today',
#  'many',
#  'dogs',
#  'know',
#  'love',
#  'product',
#  'selective',
#  'breeding',
#  'individuals',
#  'desirable',
#  'traits',
#  'either',
#  'physical',
#  'behavioral',
#  'instance',
#  'around',
#  '9,500',
#  'years',
#  'ago',
#  'ancient',
#  'peoples',
#  'began',
#  'breeding',
#  'dogs',
#  'best',
#  'able',
#  'survive',
#  'work',
#  'cold',
#  'dogs',
#  'would',
#  'become',
#  'family',
#  'sled',
#  'dogs—including',
#  'breeds',
#  'huskies',
#  'malamutes—that',
#  'remains',
#  'relatively',
#  'unchanged',
#  'today',
#  'similarly',
#  'humans',
#  'bred',
#  'german',
#  'shepherds',
#  'ability',
#  'herd',
#  'livestock',
#  'labrador',
#  'retrievers',
#  'help',
#  'collect',
#  'ducks',
#  'game',
#  'felled',
#  'hunters',
#  'sausage-shaped',
#  'dachshunds',
#  'ability',
#  'rush',
#  'burrow',
#  'badger',
#  'many',
#  'breeds',
#  'created',
#  'fill',
#  'human',
#  'needs',
#  'home',
#  'protection',
#  'vermin',
#  'control',
#  'certain',
#  'breeds',
#  'also',
#  'created',
#  'make',
#  'dogs',
#  'desirable',
#  'companions',
#  'instance',
#  'labradoodle',
#  'combines',
#  'traits',
#  'labrador',
#  'retriever',
#  'poodle',
#  'invented',
#  'attempt',
#  'create',
#  'hypoallergenic',
#  'guide',
#  'dog',
#  'modern',
#  'working',
#  'dogs',
#  'people',
#  'rely',
#  'less',
#  'dogs',
#  'daily',
#  'tasks',
#  'past',
#  'still',
#  'many',
#  'modern',
#  'jobs',
#  'pooches',
#  'domestic',
#  'dog',
#  'sense',
#  'smell',
#  '10,000',
#  '100,000',
#  'better',
#  'canines',
#  'assist',
#  'law',
#  'enforcement',
#  'sniffing',
#  'drugs',
#  'explosives',
#  'even',
#  'electronics',
#  'also',
#  'help',
#  'conservationists',
#  'find',
#  'protect',
#  'endangered',
#  'species',
#  'using',
#  'super-powered',
#  'schnozzes',
#  'assist',
#  'search',
#  'rescue',
#  'teams',
#  'wake',
#  'natural',
#  'disasters',
#  'reports',
#  'people',
#  'lost',
#  'outdoors',
#  'dogs',
#  'trained',
#  'warn',
#  'hidden',
#  'explosives',
#  'enemies',
#  'serve',
#  'allies',
#  'military',
#  'operations',
#  'dogs',
#  'assist',
#  'police',
#  'looking',
#  'jail',
#  'escapees',
#  'bodies',
#  'murder',
#  'victims',
#  'partner',
#  'instead',
#  'customs',
#  'officials',
#  'searching',
#  'contraband',
#  'drugs',
#  'elephant',
#  'ivory',
#  'still',
#  'others',
#  'lead',
#  'way',
#  'tracking',
#  'poachers',
#  'patrolling',
#  'cargo',
#  'ships',
#  'rats',
#  'might',
#  'escape',
#  'distant',
#  'harbors',
#  'exposing',
#  'forest',
#  'insect',
#  'pests',
#  'shipments',
#  'wood',
#  'abroad',
#  'similarly',
#  'dogs',
#  'sniff',
#  'early',
#  'signs',
#  'parkinson',
#  'disease',
#  'diabetes',
#  'several',
#  'types',
#  'cancer',
#  'oncoming',
#  'epileptic',
#  'seizures',
#  'antibiotic-resistant',
#  'bacteria',
#  'guide',
#  'deaf',
#  'blind',
#  'people',
#  'help',
#  'people',
#  'autism',
#  'post-traumatic',
#  'stress',
#  'disorder',
#  'manage',
#  'anxiety',
#  'living',
#  'dogs',
#  'dogs',
#  'mix',
#  'breeds—in',
#  '2015',
#  'one',
#  'study',
#  'estimated',
#  'percent',
#  'dogs',
#  'shelters',
#  'purebred',
#  'dogs',
#  'come',
#  'sizes',
#  'shapes',
#  'colors',
#  'animals',
#  'also',
#  'come',
#  'spectrum',
#  'temperaments',
#  'bulldog',
#  'might',
#  'look',
#  'fierce',
#  'cuddly',
#  'kitten',
#  'whereas',
#  'cute',
#  'cocker',
#  'spaniel',
#  'might',
#  'nip',
#  'finger',
#  'without',
#  'thinking',
#  'twice',
#  'animal',
#  'handling',
#  'expert',
#  'jack',
#  'hanna',
#  'recommends',
#  'teaching',
#  'children',
#  'always',
#  'exercise',
#  'caution',
#  'around',
#  'dog',
#  'know',
#  'instance',
#  'says',
#  'kids',
#  'ask',
#  'permission',
#  'dog',
#  'owner',
#  'trying',
#  'pet',
#  'play',
#  'animal',
#  'offering',
#  'outstretched',
#  'hand',
#  'also',
#  'allows',
#  'dog',
#  'familiarize',
#  'new',
#  'person',
#  'reaching',
#  'behind',
#  'head',
#  'see',
#  'might',
#  'make',
#  'dog',
#  'nervous',
#  'scared',
#  'finally',
#  'never',
#  'allow',
#  'children',
#  'put',
#  'faces',
#  'near',
#  'dog',
#  'muzzle',
#  'care',
#  'kind',
#  'dog',
#  'hanna',
#  'told',
#  'national',
#  'geographic',
#  'owner',
#  'may',
#  'say',
#  'well',
#  'dog',
#  'never',
#  'bit',
#  'anyone',
#  'before.',
#  'point',
#  'point',
#  'happen.',
#  'course',
#  'dogs',
#  'cared',
#  'properly',
#  'treated',
#  'respect',
#  'incredibly',
#  'loving',
#  'playful',
#  'intelligent',
#  'companions',
#  'understanding',
#  'dogs',
#  'come',
#  'pet',
#  'owners',
#  'might',
#  'learn',
#  'appreciate',
#  'canines',
#  'even',
#  'yipping',
#  'tail-wagging',
#  'dog',
#  'performs',
#  'grab',
#  'bag',
#  'treats',
#  'carry-overs',
#  'ancestors',
#  'needed',
#  'communicate',
#  'members',
#  'social',
#  'group',
#  'chasing',
#  'sticks',
#  'balls',
#  'may',
#  'linked',
#  'pursuit',
#  'prey',
#  'digging',
#  'carpet',
#  'dog',
#  'bed',
#  'echoes',
#  'wild',
#  'canid',
#  'would',
#  'prepare',
#  'sleeping',
#  'area',
#  'time',
#  'fido',
#  'stops',
#  'sniff',
#  'fire',
#  'hydrant',
#  'walk',
#  'analyzing',
#  'pheromones',
#  'left',
#  'behind',
#  'another',
#  'dog',
#  'urine',
#  'take',
#  'behaviors',
#  'granted',
#  'dogs',
#  'become',
#  'man',
#  'best',
#  'friend.',
#  'deep',
#  'inside',
#  'every',
#  'pit',
#  'bull',
#  'pomeranian',
#  'lie',
#  'hints',
#  'past',
#  'editor',
#  "'s",
#  'note',
#  'bringing',
#  'dog',
#  'household',
#  'major',
#  'responsibility',
#  '1.6',
#  'million',
#  'dogs',
#  'ended',
#  'shelters',
#  '2020',
#  'learn',
#  'keep',
#  'dog',
#  'happy',
#  'healthy',
#  'national',
#  'geographic',
#  'book',
#  'complete',
#  'guide',
#  'pet',
#  'health',
#  'behavior',
#  'happiness']

# %%
text_preparation(extracted_content[1])
# Out:
# ['common',
#  'name',
#  'domestic',
#  'dog',
#  'scientific',
#  'name',
#  'canis',
#  'familiaris',
#  'type',
#  'mammal',
#  'diet',
#  'omnivore',
#  'group',
#  'name',
#  'pack',
#  'average',
#  'life',
#  'span',
#  'wild',
#  '12',
#  'year',
#  'size',
#  'five',
#  '35',
#  'inch',
#  'shoulder',
#  'weight',
#  'three',
#  '250',
#  'pound',
#  'iucn',
#  'red',
#  'list',
#  'status',
#  'evaluate',
#  'current',
#  'population',
#  'trend',
#  'unknown',
#  'domestic',
#  'dog',
#  'term',
#  'domestic',
#  'dog',
#  'refers',
#  'several',
#  'hundred',
#  'breed',
#  'dog',
#  'world',
#  'today',
#  'animal',
#  'vary',
#  'drastically',
#  'appearance',
#  'every',
#  'dog—from',
#  'chihuahua',
#  'great',
#  'dane—is',
#  'member',
#  'specie',
#  'canis',
#  'familiaris',
#  'separate',
#  'domestic',
#  'dog',
#  'wild',
#  'canine',
#  'coyote',
#  'fox',
#  'wolf',
#  'domestic',
#  'dog',
#  'mostly',
#  'kept',
#  'pet',
#  'though',
#  'many',
#  'breed',
#  'capable',
#  'survive',
#  'whether',
#  'forest',
#  'city',
#  'street',
#  'third',
#  'household',
#  'worldwide',
#  'dog',
#  'accord',
#  '2016',
#  'consumer',
#  'insight',
#  'study',
#  'make',
#  'domestic',
#  'dog',
#  'popular',
#  'pet',
#  'planet',
#  'evolutionary',
#  'origin',
#  'dog',
#  'descend',
#  'specie',
#  'wolf',
#  'gray',
#  'wolf',
#  'canis',
#  'lupus',
#  'like',
#  'many',
#  'people',
#  'assume',
#  'fact',
#  'dna',
#  'evidence',
#  'suggests',
#  'now-extinct',
#  'wolf',
#  'ancestor',
#  'modern',
#  'dog',
#  'eurasian',
#  'however',
#  'scientist',
#  'still',
#  'work',
#  'understand',
#  'exactly',
#  'specie',
#  'give',
#  'rise',
#  'dog',
#  'dog',
#  'broke',
#  'wild',
#  'ancestor',
#  'also',
#  'matter',
#  'mystery',
#  'genetics',
#  'suggest',
#  'occur',
#  '15,000',
#  '30,000',
#  'year',
#  'ago',
#  'impossible',
#  'say',
#  'exactly',
#  'wild',
#  'wolf',
#  'specie',
#  'become',
#  'domesticate',
#  'dog',
#  'scientist',
#  'believe',
#  'process',
#  'happen',
#  'gradually',
#  'wolf',
#  'become',
#  'comfortable',
#  'human',
#  'perhaps',
#  'wolf',
#  'start',
#  'path',
#  'simply',
#  'eat',
#  'human',
#  'scrap',
#  'many',
#  'generation',
#  'later',
#  'human',
#  'might',
#  'encourage',
#  'wolf',
#  'stay',
#  'near',
#  'actively',
#  'feed',
#  'later',
#  'still',
#  'wolf',
#  'may',
#  'welcome',
#  'human',
#  'home',
#  'eventually',
#  'breed',
#  'encourage',
#  'certain',
#  'trait',
#  'thought',
#  'unfolded',
#  'thousand',
#  'year',
#  'dog',
#  'breed',
#  'today',
#  'many',
#  'dog',
#  'know',
#  'love',
#  'product',
#  'selective',
#  'breeding',
#  'individual',
#  'desirable',
#  'trait',
#  'either',
#  'physical',
#  'behavioral',
#  'instance',
#  'around',
#  '9,500',
#  'year',
#  'ago',
#  'ancient',
#  'people',
#  'begin',
#  'breeding',
#  'dog',
#  'best',
#  'able',
#  'survive',
#  'work',
#  'cold',
#  'dog',
#  'would',
#  'become',
#  'family',
#  'sled',
#  'dogs—including',
#  'breed',
#  'husky',
#  'malamutes—that',
#  'remains',
#  'relatively',
#  'unchanged',
#  'today',
#  'similarly',
#  'human',
#  'breed',
#  'german',
#  'shepherd',
#  'ability',
#  'herd',
#  'livestock',
#  'labrador',
#  'retriever',
#  'help',
#  'collect',
#  'duck',
#  'game',
#  'fell',
#  'hunter',
#  'sausage-shaped',
#  'dachshund',
#  'ability',
#  'rush',
#  'burrow',
#  'badger',
#  'many',
#  'breed',
#  'create',
#  'fill',
#  'human',
#  'need',
#  'home',
#  'protection',
#  'vermin',
#  'control',
#  'certain',
#  'breed',
#  'also',
#  'create',
#  'make',
#  'dog',
#  'desirable',
#  'companion',
#  'instance',
#  'labradoodle',
#  'combine',
#  'trait',
#  'labrador',
#  'retriever',
#  'poodle',
#  'invent',
#  'attempt',
#  'create',
#  'hypoallergenic',
#  'guide',
#  'dog',
#  'modern',
#  'work',
#  'dog',
#  'people',
#  'rely',
#  'less',
#  'dog',
#  'daily',
#  'task',
#  'past',
#  'still',
#  'many',
#  'modern',
#  'job',
#  'pooch',
#  'domestic',
#  'dog',
#  'sense',
#  'smell',
#  '10,000',
#  '100,000',
#  'well',
#  'canine',
#  'assist',
#  'law',
#  'enforcement',
#  'sniff',
#  'drug',
#  'explosive',
#  'even',
#  'electronics',
#  'also',
#  'help',
#  'conservationist',
#  'find',
#  'protect',
#  'endanger',
#  'specie',
#  'use',
#  'super-powered',
#  'schnozzes',
#  'assist',
#  'search',
#  'rescue',
#  'team',
#  'wake',
#  'natural',
#  'disaster',
#  'report',
#  'people',
#  'lose',
#  'outdoors',
#  'dog',
#  'train',
#  'warn',
#  'hidden',
#  'explosive',
#  'enemy',
#  'serve',
#  'ally',
#  'military',
#  'operation',
#  'dog',
#  'assist',
#  'police',
#  'look',
#  'jail',
#  'escapee',
#  'body',
#  'murder',
#  'victim',
#  'partner',
#  'instead',
#  'custom',
#  'official',
#  'search',
#  'contraband',
#  'drug',
#  'elephant',
#  'ivory',
#  'still',
#  'others',
#  'lead',
#  'way',
#  'track',
#  'poacher',
#  'patrol',
#  'cargo',
#  'ship',
#  'rat',
#  'might',
#  'escape',
#  'distant',
#  'harbor',
#  'expose',
#  'forest',
#  'insect',
#  'pest',
#  'shipment',
#  'wood',
#  'abroad',
#  'similarly',
#  'dog',
#  'sniff',
#  'early',
#  'sign',
#  'parkinson',
#  'disease',
#  'diabetes',
#  'several',
#  'type',
#  'cancer',
#  'oncoming',
#  'epileptic',
#  'seizure',
#  'antibiotic-resistant',
#  'bacteria',
#  'guide',
#  'deaf',
#  'blind',
#  'people',
#  'help',
#  'people',
#  'autism',
#  'post-traumatic',
#  'stress',
#  'disorder',
#  'manage',
#  'anxiety',
#  'living',
#  'dog',
#  'dog',
#  'mix',
#  'breeds—in',
#  '2015',
#  'one',
#  'study',
#  'estimate',
#  'percent',
#  'dog',
#  'shelter',
#  'purebred',
#  'dog',
#  'come',
#  'size',
#  'shape',
#  'color',
#  'animal',
#  'also',
#  'come',
#  'spectrum',
#  'temperament',
#  'bulldog',
#  'might',
#  'look',
#  'fierce',
#  'cuddly',
#  'kitten',
#  'whereas',
#  'cute',
#  'cocker',
#  'spaniel',
#  'might',
#  'nip',
#  'finger',
#  'without',
#  'think',
#  'twice',
#  'animal',
#  'handle',
#  'expert',
#  'jack',
#  'hanna',
#  'recommends',
#  'teach',
#  'child',
#  'always',
#  'exercise',
#  'caution',
#  'around',
#  'dog',
#  'know',
#  'instance',
#  'say',
#  'kid',
#  'ask',
#  'permission',
#  'dog',
#  'owner',
#  'try',
#  'pet',
#  'play',
#  'animal',
#  'offering',
#  'outstretched',
#  'hand',
#  'also',
#  'allows',
#  'dog',
#  'familiarize',
#  'new',
#  'person',
#  'reach',
#  'behind',
#  'head',
#  'see',
#  'might',
#  'make',
#  'dog',
#  'nervous',
#  'scar',
#  'finally',
#  'never',
#  'allow',
#  'child',
#  'put',
#  'face',
#  'near',
#  'dog',
#  'muzzle',
#  'care',
#  'kind',
#  'dog',
#  'hanna',
#  'told',
#  'national',
#  'geographic',
#  'owner',
#  'may',
#  'say',
#  'well',
#  'dog',
#  'never',
#  'bit',
#  'anyone',
#  'before.',
#  'point',
#  'point',
#  'happen.',
#  'course',
#  'dog',
#  'care',
#  'properly',
#  'treat',
#  'respect',
#  'incredibly',
#  'love',
#  'playful',
#  'intelligent',
#  'companion',
#  'understand',
#  'dog',
#  'come',
#  'pet',
#  'owner',
#  'might',
#  'learn',
#  'appreciate',
#  'canine',
#  'even',
#  'yipping',
#  'tail-wagging',
#  'dog',
#  'performs',
#  'grab',
#  'bag',
#  'treat',
#  'carry-over',
#  'ancestor',
#  'need',
#  'communicate',
#  'member',
#  'social',
#  'group',
#  'chase',
#  'stick',
#  'ball',
#  'may',
#  'link',
#  'pursuit',
#  'prey',
#  'dig',
#  'carpet',
#  'dog',
#  'bed',
#  'echo',
#  'wild',
#  'canid',
#  'would',
#  'prepare',
#  'sleep',
#  'area',
#  'time',
#  'fido',
#  'stop',
#  'sniff',
#  'fire',
#  'hydrant',
#  'walk',
#  'analyze',
#  'pheromone',
#  'left',
#  'behind',
#  'another',
#  'dog',
#  'urine',
#  'take',
#  'behavior',
#  'grant',
#  'dog',
#  'become',
#  'man',
#  'best',
#  'friend.',
#  'deep',
#  'inside',
#  'every',
#  'pit',
#  'bull',
#  'pomeranian',
#  'lie',
#  'hint',
#  'past',
#  'editor',
#  "'s",
#  'note',
#  'bring',
#  'dog',
#  'household',
#  'major',
#  'responsibility',
#  '1.6',
#  'million',
#  'dog',
#  'end',
#  'shelter',
#  '2020',
#  'learn',
#  'keep',
#  'dog',
#  'happy',
#  'healthy',
#  'national',
#  'geographic',
#  'book',
#  'complete',
#  'guide',
#  'pet',
#  'health',
#  'behavior',
#  'happiness']

# %% [markdown]
# 4. lemmatize

# %%
from nltk.stem import WordNetLemmatizer
